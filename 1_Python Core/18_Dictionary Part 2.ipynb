# %% [markdown]
# # Dictionary

# %%
l = [10,20,30]
#    0  1  2

# %%
hashing

55 - 55%10 - 5

40 - 40%10 - 0

# %%
[40, , , , ,55]

# %%
55

# %%
# collision

65 - 65%10 - 5

# %%
[40, , , , ,55]
             |
            65
             |
            45

# %%
key: value
5 : 65
3 : 45

# %%
# unordered data structure
# { key: value}
d = {"A":"Indore", 5: 65, "goa": 45}

print(d)
# Out:
# {'A': 'Indore', 5: 65, 'goa': 45}

# %%
print(d['goa'])
# Out:
# 45

# %%
print(d[45])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-3-9d9ad480aa99> in <module>
# ----> 1 print(d[45])
#
# KeyError: 45

# %%
print(d[5])
# Out:
# 65

# %%
print(d['5'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-5-10a63781ac18> in <module>
# ----> 1 print(d['5'])
#
# KeyError: '5'

# %%
print(type(d))
# Out:
# <class 'dict'>

# %%
print(type(d['goa']))
# Out:
# <class 'int'>

# %%
d = {}
print(d)
print(type(d))
# Out:
# {}
# <class 'dict'>

# %%
color = {
    "red":[255,0,0],
    "green":[0,255,0],
    "blue":[0,0,255]
}
print(color['red'])
# Out:
# [255, 0, 0]

# %%
color['yellow']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-5341b40bca8b> in <module>
# ----> 1 color['yellow']
#
# KeyError: 'yellow'

# %%
color = {
    "red":[255,0,0],
    "green":[0,255,0],
    "blue":[0,0,255]
}

print(type(color['red']))
# Out:
# <class 'list'>

# %%
print(color['red'][0])
# Out:
# 255

# %%
x = color['red']

print(x[0])
# Out:
# 255

# %%
d = {1:1, 2:2, 3:4}

print(d[1])
# Out:
# 1

# %%
d = {[1,2]:1, 2:2, 3:4}

print(d[1])            # key should not be mutable
#  key should be immutable
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3d8cc47c5cb3> in <module>
# ----> 1 d = {[1,2]:1, 2:2, 3:4}
#       2
#       3 print(d[1])
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# # Dictionary functions

# %%
d = {1:1, 2:4, 3:9, 4:16}

print(len(d))
# Out:
# 4

# %%
str(d)
# Out:
# '{1: 1, 2: 4, 3: 9, 4: 16}'

# %%
s = str(d)
print(s[0])
# Out:
# {

# %%
d = {1:1, 2:4, 3:9, 4:16}

print(sum(d))
# Out:
# 10

# %%
d = {1:1, "B":4, 3:9, 4:16}

print(sum(d))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-b413fc134292> in <module>
#       1 d = {1:1, "B":4, 3:9, 4:16}
#       2
# ----> 3 print(sum(d))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
d = {1:1, 2:4, 3:9, 4:16}

print(max(d))
# Out:
# 4

# %%
d = {1:1, "D":4, 3:9, 4:16}

print(max(d))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-24-6441419caa8e> in <module>
#       1 d = {1:1, "D":4, 3:9, 4:16}
#       2
# ----> 3 print(max(d))
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# # Dictionary Methods

# %%
p = {1: "Apple", "orange": [2,3,4], "2": 3}

# %% [markdown]
# #### get

# %%
print(p.get("orange"))
# Out:
# [2, 3, 4]

# %%
print(p.get(7))
# Out:
# None

# %%
None -> NULL

# %%
print(p.get(1, "Key not found"))
# Out:
# Apple

# %%
print(p.get(10, "Key not found"))
# Out:
# Key not found

# %%
p[2]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-30-21c545b39f61> in <module>
# ----> 1 p[2]
#
# KeyError: 2

# %%
p['2']
# Out:
# 3

# %%
f = {1:1, 2:1, 3:2, 4:3}

print(f.get(4,0) + f.get(7,5))
#         3      +      5
# Out:
# 8

# %% [markdown]
# #### clear

# %%
r = {1:"A", 2:"Zara"}
print(r)
# Out:
# {1: 'A', 2: 'Zara'}

# %%
r.clear()
print(r)
# Out:
# {}

# %% [markdown]
# #### keys

# %%
r = {1:"A", 2:"Zara", 3:"goa", "raw":77}

print(r.keys())
# Out:
# dict_keys([1, 2, 3, 'raw'])

# %%
print(list(r.keys()))
# Out:
# [1, 2, 3, 'raw']

# %% [markdown]
# #### values

# %%
r = {1:"A", 2:"Zara", 3:"goa", "raw":77}

print(r.values())
# Out:
# dict_values(['A', 'Zara', 'goa', 77])

# %%
print(list(r.values()))
# Out:
# ['A', 'Zara', 'goa', 77]

# %%
r = {3:"A", 2:"Zara", 3:"goa", "raw":77}

print(len(r))
# Out:
# 3

# %%
print(r)
# Out:
# {3: 'goa', 2: 'Zara', 'raw': 77}

# %% [markdown]
# #### items

# %%
r = {3: 'goa', 2: 'Zara', 'raw': 77}

print(r.items())
# Out:
# dict_items([(3, 'goa'), (2, 'Zara'), ('raw', 77)])

# %%
print(list(r.items()))
# Out:
# [(3, 'goa'), (2, 'Zara'), ('raw', 77)]

# %%
[(3, 'goa'), (2, 'Zara'), ('raw', 77)]
#    0           1             2
# 0    1      0     1        0     1

# %%
x --> 10
y --> 20
z --> 30

# %%
d = {'x':10, 'y':20, 'z': 30}

#           ('x', 10)
for a,b in d.items():
    print(a,'-->',b)
# Out:
# x --> 10
# y --> 20
# z --> 30

# %%
for a in d.values():
    print(a)
# Out:
# 10
# 20
# 30

# %% [markdown]
# **WAP to merge two dictionaries**

# %%
d1 = {1:"Hi", 2:"Bye"}
d2 = {3:"indore", 4:"goa"}

d1.update(d2)
print(d1)
# Out:
# {1: 'Hi', 2: 'Bye', 3: 'indore', 4: 'goa'}

# %%
d1 = {1:"Hi", 2:"Bye"}

d2 = d1.copy()

d2
# Out:
# {1: 'Hi', 2: 'Bye'}

# %% [markdown]
# **WAP to sum all the values in a dictionary**

# %%
d = {1:11, 2:21, 3:22, 4:31}

print(sum(d.values()))
# Out:
# 85

# %%
s = 0
for i in d:
    s = s + d[i]
print("Sum =",s)
# Out:
# Sum= 85

# %% [markdown]
# **WAP to check a dictionary is empty or not**

# %%
d = {}
if len(d) == 0:
    print("Empty")
# Out:
# Empty

# %%
{1:1, 2:4, 3:9, 4:16, 5:25, 6:36......10:100}

# %%
d = {}

for i in range(1,11):
    d[i] = i * i

print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}
