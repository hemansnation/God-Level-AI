# %% [markdown]
# # Object Orientated Programming

# %% [markdown]
# 7 properties of OOPs
#
# 1. Class
#             Updated version of structure
#             Collection of variables and methods.
#             Class is a blueprint.
#
# 2. Object
#             Run time or real time entity.
#             hash code - id
#
# 3. Abstraction and Encapsulation
#             Abstraction - Showing only essential features without showing any background details.
#             Encapsulation - wrapping up of data in a single unit.
#
# 4. Inheritance
#             Acquiring Properties of one class into another.
#             Code reuse.
#             - Single Level
#             - Multi Level
#             - Hierarchical
#             - Multiple
#             - Hybrid
#
# 5. Polymorphism
#             same name multiple fuctionalities.
#             - Method Overloading
#             - Method Overriding
#             add()
#             add(x,y)
#             add(a,b,c)
#             add()
#
# 6. Dynamic Memory Allocation
#             Run time memory allocation
#
#
# 7. Message passing
#             Communication between objects

# %%
int a = 10;

struct student{
    int a;
    float p;
    char f;
}

struct student s1;
           int a;

# %%
class Cricket:
    
    def bat():
        print("Batting")

# %%
bat()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7004d47d541c> in <module>
# ----> 1 bat()
#
# NameError: name 'bat' is not defined

# %%
# self ---> current object

# %%
class Cricket:
    
    def bat(self):
        print("Batting")

x = Cricket()

# %%
x.bat()
# Out:
# Batting

# %%
print(x)
# Out:
# <__main__.Cricket object at 0x000002631117DA60>

# %%
print(id(x))
# Out:
# 2624511793760

# %%
print(Cricket())
# Out:
# <__main__.Cricket object at 0x0000026311187550>

# %%
x = Cricket()

# %%
TV blueprint   - class
- smart tv
- colors
- usb
- hdmi

Actual TV   - object

Remote  - reference

# %%
class Test:
    
    def add(self):
        print("This is add method")
    
    def sub(self, a, b): # self = t1
        print(a)
        print(b)
    
t1 = Test()
t2 = Test()

# %%
t1.add()
t2.add()
# Out:
# This is add method
# This is add method

# %%
t1.sub(10,20)
# Out:
# 10
# 20

# %%
t2.sub(7,11)
# Out:
# 7
# 11

# %%
t1.sub()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-5-53d284fb333d> in <module>
# ----> 1 t1.sub()
#
# TypeError: sub() missing 2 required positional arguments: 'a' and 'b'

# %%
class Test:
    
    def add(self):
        print(self)
        print("This is add method")
    
    def sub(self, a, b): # self = t1
        print(a)
        print(b)
    
t1 = Test()
t2 = Test()

print(t1)
t1.add()
print()
print(t2)
t2.add()
# Out:
# <__main__.Test object at 0x000001FD597E8B80>
# <__main__.Test object at 0x000001FD597E8B80>
# This is add method
#
# <__main__.Test object at 0x000001FD597E8BE0>
# <__main__.Test object at 0x000001FD597E8BE0>
# This is add method

# %% [markdown]
# ### Local variables and class variables

# %%
class Test:
    def add(self):
        print("This is add method")
    
    def sub(self, a, b): # a and b are the local variables of sub method
        self.x = a       # t1.x = 10   t2.x = 11   # x & y are class variables
        self.y = b       # t1.y = 20   t2.y = 12   # or instance variables
    
    def show(self):
        print(self.x)
        print(self.y)

# %%
t1 = Test()
t2 = Test()

# %%
t1.add()
t2.add()
# Out:
# This is add method
# This is add method

# %%
t1.sub(10,20)
t2.sub(11,12)

# %%
t1.show()
# Out:
# 10
# 20

# %%
t2.show()
# Out:
# 11
# 12

# %%
print(t1.x)
print(t1.y)
# Out:
# 10
# 20

# %%
print(t1.a)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-80e8f66c0508> in <module>
# ----> 1 print(t1.a)
#
# AttributeError: 'Test' object has no attribute 'a'

# %%
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-fc17d851ef81> in <module>
# ----> 1 print(x)
#
# NameError: name 'x' is not defined

# %%
print(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-bca0e2660b9f> in <module>
# ----> 1 print(a)
#
# NameError: name 'a' is not defined

# %% [markdown]
# # Constructor
#
# It is a special member method of a class

# %%
__init__()   # magic method  //  dunders

# %%
class Cat:
    
    def __init__(self):
        print("This is constructor")

# %%
f = Cat()
# Out:
# This is constructor

# %%
Cat()
# Out:
# This is constructor

# %% [markdown]
# ### paramatrized constructor

# %%
class Car:
    def __init__(self, x):
        self.y = x

# %%
f = Car(10)

# %%
print(f.y)
# Out:
# 10

# %%
class Rectangle:
    def __init__(self,a,b):
        self.a = a
        self.b = b


r = Rectangle(8,7)

print(r.a)
print(r.b)
# Out:
# 8
# 7

# %% [markdown]
# # Questions
#
# **WAP to create a class to reverse a string word by word**

# %%
"This is an apple"

"apple an is this"

# %%
class Test:
    
    def sentence(self,s):
        l = s.split(" ")
        l.reverse()
        s = " ".join(l)
        return s

t = Test()
a = input("Enter a string")
t.sentence(a)
# Out:
# Enter a stringthis is an apple
# 'apple an is this'

# %% [markdown]
# **WAP to create a class that can calculate area of circle, rectangle, square and  triangle**

# %% [markdown]
# # Inheritance
#
# Aquiring properties of one class into another.
#
# 1. Single Level
# 2. Multi Level
# 3. Hierarchical
# 4. Multiple
# 5. Hybrid

# %% [markdown]
# # Single Level Inheritance

# %%
class A:                              # parent class / super class / base class
    
    def add(self):
        print("Add from class A")
    

class B(A):                           # child class / sub class / derived class
    
    def sub(self):
        print("Sub from class B")
    
x = A()
y = B()

# %%
x.add()
# Out:
# Add from class A

# %%
y.add()
# Out:
# Add from class A

# %%
y.sub()
# Out:
# Sub from class B

# %%
x.sub()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-2b0748566ee1> in <module>
# ----> 1 x.sub()
#
# AttributeError: 'A' object has no attribute 'sub'

# %% [markdown]
# # Inheritance with constructor

# %%
class A:
    
    def __init__(self):
        print("Init A")
    
    def add(self):
        print("Add from class A")
    

class B(A):
    
    def __init__(self):
        print("Init B")
    
    def sub(self):
        print("Sub from class B")
    
x = A()
y = B()
# Out:
# Init A
# Init B

# %% [markdown]
# # Multi Level Inheritance

# %%
A
|
B
|
C

# %%
class A:
   
    def add(self):
        print("Add from class A")

class B(A):
    
    def sub(self):
        print("Sub from class B")
    
class C(B):
    
    def show(self):
        print("Show from class C")
    
z = C()
z.show()
z.sub()
z.add()
# Out:
# Show from class C
# Sub from class B
# Add from class A

# %% [markdown]
# # Hierarchical Inheritance

# %%
   A
B     C

# %%
class A:
   
    def add(self):
        print("Add from class A")

class B(A):
    
    def sub(self):
        print("Sub from class B")
    
class C(A):
    
    def show(self):
        print("Show from class C")
    
z = C()
z.show()
# Out:
# Show from class C

# %%
z.sub()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-10-b1c379b42a74> in <module>
# ----> 1 z.sub()
#
# AttributeError: 'C' object has no attribute 'sub'

# %%
z.add()
# Out:
# Add from class A

# %% [markdown]
# # Multiple Inheritance
#
# C3 algorithm to solve ambiguity error
#
# MRO - Method Resolution Order

# %%
A     B
   C

# %%
class A:
   
    def add(self):
        print("Add from class A")

class B:
    
    def add(self):
        print("Add from class B")
    
class C(A,B):
    
    def show(self):
        print("Show from class C")

# %%
print(C.__mro__)
# Out:
# (<class '__main__.C'>, <class '__main__.A'>, <class '__main__.B'>, <class 'object'>)

# %%
z = C()
z.show()
# Out:
# Show from class C

# %%
z.add()
# Out:
# Add from class A

# %%
class A:
   
    def add(self):
        print("Add from class A")

class B:
    
    def add(self):
        print("Add from class B")
    
class C(B,A):
    
    def show(self):
        print("Show from class C")

e = C()
e.add()
# Out:
# Add from class B

# %%
print(C.__mro__)
# Out:
# (<class '__main__.C'>, <class '__main__.B'>, <class '__main__.A'>, <class 'object'>)

# %% [markdown]
# # Hybrid Inheritance

# %%
    A
B       C
    D

# %%
class A:
   
    def add(self):
        print("Add from class A")

class B(A):
    
    def sub(self):
        print("Add from class B")
    
class C(A):
    
    def show(self):
        print("Show from class C")

class D(B,C):
    
    def display(self):
        print("Display from class D")
    

d = D()
d.display()
d.show()
d.sub()
d.add()
# Out:
# Display from class D
# Show from class C
# Add from class B
# Add from class A
