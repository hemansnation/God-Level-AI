# %% [markdown]
# # Strings

# %%
s = "Indore"
print(s)
# Out:
# Indore

# %%
s = "A"
print(s)
print(type(s))
# Out:
# A
# <class 'str'>

# %%
a = "10.5"
print(type(a))
# Out:
# <class 'str'>

# %%
#        -1
s = "Indore"
#    012345
print(s[0])
# Out:
# I

# %%
print(s[3])
# Out:
# o

# %%
print(s[-1])
# Out:
# e

# %%
l = [1,2]   # mutable
l[0] = 10
print(l)
# Out:
# [10, 2]

# %%
s = "Indore"         # immutable objects
s[0] = "A"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-7727795c72fa> in <module>
#       1 s = "Indore"
# ----> 2 s[0] = "A"
#
# TypeError: 'str' object does not support item assignment

# %%
s = "Indore"
s = "A"
print(s)
# Out:
# A

# %%
1 + 1 = 2 # int - immutable

# %% [markdown]
# # String Slicing

# %%
s = "Communication"
#    0123456789

# %%
print(s[1:4])
# Out:
# omm

# %%
print(s[4:1])

# %%
s[-9:-4]
# Out:
# 'unica'

# %%
s
# Out:
# 'Communication'

# %%
s[0::2] #steps
# Out:
# 'Cmuiain'

# %%
s[::-1]
# Out:
# 'noitacinummoC'

# %%
n = len(s) - 1
print(n)
# Out:
# 12

# %%
print(s[n])
# Out:
# n

# %%
s
# Out:
# 'Communication'

# %%
print(s[1:4:-1])

# %%
print(s[4:1:-1])
# Out:
# umm

# %%
print(s[::0])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-233ebc5e122e> in <module>
# ----> 1 print(s[::0])
#
# ValueError: slice step cannot be zero

# %% [markdown]
# # String Functions

# %%
s = "India"

print(len(s))
# Out:
# 5

# %%
A - 65  # ASCII
B - 66

Z - 90

space - 32

a - 97
z - 122

# %%
print(max(s))
# Out:
# n

# %%
print(min(s))
# Out:
# I

# %%
"A" + "B"
# Out:
# 'AB'

# %%
print(sum(s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-09c2c04bb2d7> in <module>
# ----> 1 print(sum(s))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # Boolean

# %%
print(type(True))
# Out:
# <class 'bool'>

# %%
print(bool(10))
# Out:
# True

# %%
print(bool(1))
# Out:
# True

# %%
print(bool(0))
# Out:
# False

# %%
print(bool('A'))
# Out:
# True

# %%
print(bool("India"))
# Out:
# True

# %%
print(bool(" "))
# Out:
# True

# %%
print(bool(""))
# Out:
# False

# %% [markdown]
# # String Methods
#
# #### join

# %%
l = ["A","C","D","B"]
s = "*"

print(s.join(l))
# Out:
# A*C*D*B

# %%
l = ["A","C","D","B"]
s = "+"

print(s.join(l))
# Out:
# A+C+D+B

# %%
l = ["A","C","D","B"]
s = " "

print(s.join(l))
# Out:
# A C D B

# %%
l = ["A","C","D","B"]
s = ""

print(s.join(l))
# Out:
# ACDB

# %%
l = ["A","C","D","B"]
print(" + ".join(l))
# Out:
# A + C + D + B

# %% [markdown]
# #### replace

# %%
r = "This is the best momo"

print(r.replace("momo","tea"))
# Out:
# This is the best tea

# %%
r = "This is the best momo, best in the town"

print(r.replace("best","good"))
# Out:
# This is the good momo, good in the town

# %% [markdown]
# #### upper and lower

# %%
a = "India"
print(a.upper())
# Out:
# INDIA

# %%
print(a.lower())
# Out:
# india

# %% [markdown]
# #### split

# %%
r = "Hello world rahul"

print(r.split(" "))
# Out:
# ['Hello', 'world', 'rahul']

# %%
r = "Helloworld rahul"

print(r.split("w"))
# Out:
# ['Hello', 'orld rahul']

# %%
r = "Helloworld rahul"

print(r.split(sep=" "))
# Out:
# ['Helloworld', 'rahul']

# %%
r.split?

# %% [markdown]
# # Questions

# %%
s = "1+2+3+4+5"
#    01234

# %%
s.split("+")
# Out:
# ['1', '2', '3', '4', '5']

# %% [markdown]
# **WAP to print length of a string without using len function**

# %% [markdown]
# a = "remote"
#
# a <= 2--> "invalid"
#
# rete
#
# abc  --> abbc

# %%
n = input("Enter a string: ")

if len(n) <= 2:
    print("Invalid String")
else:
    print(n[:2] + n[-2:])
# Out:
# Enter a string: abc
# abbc

# %%
"restart"

resta@t

"level"

leve@

# %%
s  = input("enter a string:")
i = 0

while i<len(s):
    i = i+1
print(i)
# Out:
# enter a string:hello
# 5
