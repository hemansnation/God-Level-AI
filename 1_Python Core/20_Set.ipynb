# %% [markdown]
# # Set
#
# unordered and unindexed
#
# sets are mutable

# %%
n = {1,2,3,4}
print(n)
# Out:
# {1, 2, 3, 4}

# %%
print(type(n))
# Out:
# <class 'set'>

# %%
s = {}
print(type(s))
# Out:
# <class 'dict'>

# %%
s = set()
print(type(s))
# Out:
# <class 'set'>

# %%
n = {33,3,4,6,6,7}
print(n)
# Out:
# {33, 3, 4, 6, 7}

# %%
print(33 in n)
# Out:
# True

# %%
n = {33,3,4,6,6,7}

for i in n:
    print(i)
# Out:
# 33
# 3
# 4
# 6
# 7

# %%
print(n[0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-2a397f3e1c14> in <module>
# ----> 1 print(n[0])
#
# TypeError: 'set' object is not subscriptable

# %% [markdown]
# # Set operations
#
# #### union

# %%
f = {1,2,3,4,5,6}
s = {4,5,6,7,8,9}

print(f | s)  # union
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %% [markdown]
# #### internsection

# %%
print(f & s)  # intersection
# Out:
# {4, 5, 6}

# %% [markdown]
# #### difference

# %%
print(f)
print(s)

# {1, 2, 3, 4, 5, 6}  -  {4, 5, 6, 7, 8, 9}
# Out:
# {1, 2, 3, 4, 5, 6}
# {4, 5, 6, 7, 8, 9}

# %%
print(f - s)
# Out:
# {1, 2, 3}

# %%
print(s - f)
# Out:
# {8, 9, 7}

# %% [markdown]
# #### Symmetric

# %%
print(f)
print(s)
# Out:
# {1, 2, 3, 4, 5, 6}
# {4, 5, 6, 7, 8, 9}

# %%
# {1, 2, 3, 4, 5, 6}  ^  {4, 5, 6, 7, 8, 9}
print(f ^ s)
# Out:
# {1, 2, 3, 7, 8, 9}

# %% [markdown]
# # Sets functions

# %%
a = {1, 2, 3, 7, 8, 9, 9}

# %%
print(len(a))

print(max(a))

print(min(a))

print(sum(a))
# Out:
# 6
# 9
# 1
# 30

# %%
s = {'a', 10, 'b'}
print(sum(s))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-a704b8c0eb3c> in <module>
#       1 s = {'a', 10, 'b'}
# ----> 2 print(sum(s))
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# # set methods
#
# #### add

# %%
s = {1,2,3}

s.add(-7)
print(s)
# Out:
# {1, 2, 3, -7}

# %% [markdown]
# #### clear

# %%
s.clear()
print(s)
# Out:
# set()

# %% [markdown]
# #### copy

# %%
s = {1,2,3}

c = s.copy()

print(c)
# Out:
# {1, 2, 3}

# %%
print(s)
# Out:
# {1, 2, 3}

# %% [markdown]
# #### pop

# %%
s = {1,2,3}

s.pop()
print(s)
# Out:
# {2, 3}

# %% [markdown]
# #### remove

# %%
n = {1,2,3,4,5,6,6}

print(n)

n.add(13)

print(n)

n.remove(5)
# Out:
# {1, 2, 3, 4, 5, 6}
# {1, 2, 3, 4, 5, 6, 13}

# %%
print(n)
# Out:
# {1, 2, 3, 4, 6, 13}

# %% [markdown]
# #### update

# %%
x = {1,2,3}
y = {4,23,5,6}

x.update(y)

print(x)
# Out:
# {1, 2, 3, 4, 5, 6, 23}

# %%
print(y)
# Out:
# {4, 5, 6, 23}

# %% [markdown]
# # Frozenset

# %%
s = frozenset([2,4,'a','c'])  # immutable

print(s)
# Out:
# frozenset({2, 4, 'c', 'a'})

# %%
s.add(5)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-10e71b13494c> in <module>
# ----> 1 s.add(5)
#
# AttributeError: 'frozenset' object has no attribute 'add'

# %%
s = frozenset({1,2,3})

# %%
print(s)
# Out:
# frozenset({1, 2, 3})

# %%
x = {1,2,3}
y = {1,2,3}
print(x == y)
# Out:
# True

# %%
a = {1,2,3,4,5,6}
b = {4,5,6}

print(a == b)
# Out:
# False

# %%
print(a <= b)  # a is a subset of b
# Out:
# False

# %%
print(b <= a)
# Out:
# True

# %%
print(a < b)  # a is proper subset of b
# Out:
# False

# %%
print(b < a)
# Out:
# True

# %%
print(a != b)
# Out:
# True

# %%
print(b != a)
# Out:
# True
