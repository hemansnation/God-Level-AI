# %% [markdown]
# # Exception
#
# run time errors

# %%
a = 0
b = 1

print(b / a)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-1-cd8e6eb58946> in <module>
#       2 b = 1
#       3
# ----> 4 print(b / a)
#
# ZeroDivisionError: division by zero

# %%
print("7" + 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-2-2a91f7ddcbf5> in <module>
# ----> 1 print("7" + 4)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print(y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-d9183e048de3> in <module>
# ----> 1 print(y)
#
# NameError: name 'y' is not defined

# %% [markdown]
# # Exception names
#
# 1. ImportError
# 2. IndexError
# 3. NameError
# 4. SyntaxError
# 5. TypeError
# 6. ValueError
#
#
# # Exception Handling
#
# try - a block that might contains an exception
#
# except - contains the exception message

# %%
try:
    a = 7
    b = 0
    print(a/b)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
# Out:
# An error occured. Do not divide by zero

# %%
try:
    a = 7
    b = 0
    print(a/b)
except NameError:
    print("An error occured. Do not divide by zero")
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-5-c59de702b121> in <module>
#       2     a = 7
#       3     b = 0
# ----> 4     print(a/b)
#       5 except NameError:
#       6     print("An error occured. Do not divide by zero")
#
# ZeroDivisionError: division by zero

# %%
help(ZeroDivisionError)
# Out:
# Help on class ZeroDivisionError in module builtins:
#
# class ZeroDivisionError(ArithmeticError)
#  |  Second argument to a division or modulo operation was zero.
#  |
#  |  Method resolution order:
#  |      ZeroDivisionError
#  |      ArithmeticError
#  |      Exception
#  |      BaseException
#  |      object
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, /, *args, **kwargs)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from BaseException:
#  |
#  |  __delattr__(self, name, /)
#  |      Implement delattr(self, name).
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __reduce__(...)
#  |      Helper for pickle.
#  |
#  |  __repr__(self, /)
#  |      Return repr(self).
#  |
#  |  __setattr__(self, name, value, /)
#  |      Implement setattr(self, name, value).
#  |
#  |  __setstate__(...)
#  |
#  |  __str__(self, /)
#  |      Return str(self).
#  |
#  |  with_traceback(...)
#  |      Exception.with_traceback(tb) --
#  |      set self.__traceback__ to tb and return self.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from BaseException:
#  |
#  |  __cause__
#  |      exception cause
#  |
#  |  __context__
#  |      exception context
#  |
#  |  __dict__
#  |
#  |  __suppress_context__
#  |
#  |  __traceback__
#  |
#  |  args

# %%
try:
    a = 7
    b = 0
    print(a/b)
    print("Finish")
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
# Out:
# An error occured. Do not divide by zero

# %%
try:
    a = 7
    b = 2
    print(a/b)
    print("Finish")
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
# Out:
# 3.5
# Finish

# %%
try:
    a = 10
    print("Hi" + a)
    print(a / 2)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
except TypeError:
    print("Error Occured")
# Out:
# Error Occured

# %%
try:
    a = 10
    print("Hi" + a)
    print(a / 2)
except ZeroDivisionError:
    print("An error occured. Do not divide by zero")
except (TypeError, ValueError):
    print("Error Occured")
# Out:
# Error Occured

# %%
try:
    w = "indore"
    print(w/0)
except:
    print("Something went wrong")
# Out:
# Something went wrong

# %%
w = "indore"
print(w/0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-12-dff75862ee41> in <module>
#       1 w = "indore"
# ----> 2 print(w/0)
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %% [markdown]
# # Else

# %%
try:
    print(1)
except ZeroDivisionError:
    print(2)
else:
    print(3)
# Out:
# 1
# 3

# %%
try:
    print(1/0)
except ZeroDivisionError:
    print(2)
else:
    print(3)
# Out:
# 2

# %% [markdown]
# # finally

# %%
try:
    print("Hello")
except:
    print("Error")
finally:
    print("finally block")
# Out:
# Hello
# finally block

# %%
try:
    print("Hello" + 5)
except:
    print("Error")
finally:
    print("finally block")
# Out:
# Error
# finally block

# %%
try:
    print(1)
except:
    print(2)
finally:
    print(3)
# Out:
# 1
# 3

# %%
try:
    print(1)
except:
    print(2)
else:
    print(4)
finally:
    print(3)
# Out:
# 1
# 4
# 3

# %% [markdown]
# # Raise exception

# %%
print(1)
raise ValueError
print(2)
# Out:
# 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-19-990863ff3a0f> in <module>
#       1 print(1)
# ----> 2 raise ValueError
#       3 print(2)
#
# ValueError:

# %%
raise TypeError
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-20-edb832a6149f> in <module>
# ----> 1 raise TypeError
#
# TypeError:

# %%
try:
    print(1/0)
except ZeroDivisionError:
    print(2)
# Out:
# 2

# %%
try:
    print(1/0)
except ZeroDivisionError:
    print(2)
    raise ValueError
# Out:
# 2
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# <ipython-input-22-dcf9ac762d91> in <module>
#       1 try:
# ----> 2     print(1/0)
#       3 except ZeroDivisionError:
#
# ZeroDivisionError: division by zero
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-dcf9ac762d91> in <module>
#       3 except ZeroDivisionError:
#       4     print(2)
# ----> 5     raise ValueError
#
# ValueError:

# %%
a = "123"
raise NameError("Invalid Name")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-f0befb2c5c60> in <module>
#       1 a = "123"
# ----> 2 raise NameError("Invalid Name")
#
# NameError: Invalid Name
