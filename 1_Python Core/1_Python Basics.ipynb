# %%
print("Hello Data Science")
print("ABC")
# Out:
# Hello Data Science
# ABC

# %%
print("Hello World")
# Out:
# Hello World

# %% [markdown]
# # Python Basics
#
# This is the first session of Data Science

# %%
print("Hello World")
# Out:
# Hello World

# %%
print("Hello\nWorld")   # new line character
# Out:
# Hello
# World

# %%
print("Hello\tWorld")  # horizontal tab
# Out:
# Hello	World

# %% [markdown]
# # Variables

# %%
a = 10
print(a)
# Out:
# 10

# %%
b = 10.5
print(b)
# Out:
# 10.5

# %%
c = "Indore"
print(c)
# Out:
# Indore

# %%
a = 10
print(a)
print(type(a))
# Out:
# 10
# <class 'int'>

# %%
b = 10.5
print(type(b))
# Out:
# <class 'float'>

# %%
c = "Indore"
print(type(c))
# Out:
# <class 'str'>

# %%
d = 'A'
print(d)
print(type(d))
# Out:
# A
# <class 'str'>

# %% [markdown]
# # User Input

# %%
x = input()
print(x)
# Out:
# 10
# 10

# %%
x = input("Enter Your Name ")
print(x)
# Out:
# Enter Your Name Himanshu
# Himanshu

# %%
x = input("Enter Your Name ")

print("Hello",x)
# Out:
# Enter Your Name Himanshu
# Hello Himanshu

# %% [markdown]
# ### WAP to enter 2 numbers from user and print addition of them.

# %%
a = input("Enter 1st Number: ")
b = input("Enter 2nd Number: ")

c = a + b

print(c)
# Out:
# Enter 1st Number: 10
# Enter 2nd Number: 20
# 1020

# %% [markdown]
# ### Type Casting

# %%
a = 10.5
b = int(a)
print(b)
# Out:
# 10

# %%
print(type(b))
# Out:
# <class 'int'>

# %%
a = "10"
print(type(a))
b = int(a)
print(type(b))
# Out:
# <class 'str'>
# <class 'int'>

# %%
"10" + "20"
# Out:
# '1020'

# %%
10 + 20
# Out:
# 30

# %%
a = int(input("Enter 1st Number: "))
b = int(input("Enter 2nd Number: "))

c = a + b

print(c)
# Out:
# Enter 1st Number: 10
# Enter 2nd Number: 20
# 30

# %%
a = int(input("Enter 1st Number: "))
b = int(input("Enter 2nd Number: "))

c = a + b

print("Addition = ",c)
# Out:
# Enter 1st Number: 10
# Enter 2nd Number: 20
# Addition =  30

# %%
a = input("Enter 1st Number: ")
b = input("Enter 2nd Number: ")

c = a + b

print("Addition = ",c)
# Out:
# Enter 1st Number: 10
# Enter 2nd Number: 20
# Addition =  1020

# %%
a = input("Enter 1st Number: ")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-27-b9fcb35ef44b> in <module>
# ----> 1 a = input("Enter 1st Number: ")
#
# ~\anaconda3\envs\pytorch\lib\site-packages\ipykernel\kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~\anaconda3\envs\pytorch\lib\site-packages\ipykernel\kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
