# %% [markdown]
# # Functions

# %%
print("Hello")
# Out:
# Hello

# %%
def indore():                  # definition of a function
    print("Hello Indore")
    print("I am the best!")

# %%
indore()                     # calling of a function
# Out:
# Hello Indore
# I am the best!

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
max?

# %%
def paint():
    print(1)
    print(2)
    print(3)

paint()
# Out:
# 1
# 2
# 3

# %%
paint()
print("Hello")
paint()
print("Hello")
paint()
# Out:
# 1
# 2
# 3
# Hello
# 1
# 2
# 3
# Hello
# 1
# 2
# 3

# %%
hello()

def hello():
    print("Hello User")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-ec0ffb3daaa0> in <module>
# ----> 1 hello()
#       2
#       3 def hello():
#       4     print("Hello User")
#
# NameError: name 'hello' is not defined

# %% [markdown]
# # Arguments

# %%
print("Hello")
# Out:
# Hello

# %%
def indore(a):         # a = "Hi"
    print(a + "!!")

# %%
indore("Hi")
# Out:
# Hi!!

# %%
indore("Hello")
indore("India")
indore("Chennai")
# Out:
# Hello!!
# India!!
# Chennai!!

# %%
def add(x , y):
    print(x + y)

# %%
add(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-fb866b66e1c7> in <module>
# ----> 1 add(10)
#
# TypeError: add() missing 1 required positional argument: 'y'

# %%
add()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-d5d29de3ed94> in <module>
# ----> 1 add()
#
# TypeError: add() missing 2 required positional arguments: 'x' and 'y'

# %%
add(1,2,3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-ff1b6584ceb8> in <module>
# ----> 1 add(1,2,3)
#
# TypeError: add() takes 2 positional arguments but 3 were given

# %%
def add(x , y):
    print(x + y)

# %%
add(10,20)
# Out:
# 30

# %%
add(7,8)
# Out:
# 15

# %%
1. Create a function which takes a value and print reverse of it

# %%
2. Create a function which takes a value and check if it a pallindrome or not

# %%
def add(v):          # local variable
    v += 1
    print(v)         #8

add(7)
print(v)
# Out:
# 8
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-e2cb702230d4> in <module>
#       4
#       5 add(7)
# ----> 6 print(v)
#
# NameError: name 'v' is not defined

# %%
x = 2                # global variable
def add(x):          # local variable
    x += 1
    print(x)         #8

add(7)
print(x)
# Out:
# 8
# 2

# %% [markdown]
# # Return Statement

# %%
def play(x , y):
    if x >= y:
        return x
    else:
        return y

print(play(5,3))
# Out:
# 5

# %%
a = play(7,9)
#      9

print(a)
# Out:
# 9

# %%
l = [1,2,3]
print(max(l))
# Out:
# 3

# %%
b = min(l)
print(b)
# Out:
# 1

# %%
def sub(x,y):
    t = x + y
    return t
    print("Hello")

print(sub(12,11))
# Out:
# 23

# %%
def pre():
    print(1)
    print(2)
    return
    print(3)
    print(4)
    
pre()
# Out:
# 1
# 2

# %% [markdown]
# # Default Arguments

# %%
"Hello" * 3
# Out:
# 'HelloHelloHello'

# %%
def say(msg, times=1):
    print(msg * times)

# %%
say("Hi")
# Out:
# Hi

# %%
say("Hi", 3)
# Out:
# HiHiHi

# %%
say(times=4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-3a322e9040a0> in <module>
# ----> 1 say(times=4)
#
# TypeError: say() missing 1 required positional argument: 'msg'

# %%
say(times=4, "Bye")
# Out:
#   File "<ipython-input-16-bfb693be80d9>", line 1
#     say(times=4, "Bye")
#                  ^
# SyntaxError: positional argument follows keyword argument

# %%
say(times=4, msg="Bye")
# Out:
# ByeByeByeBye

# %%
def say(msg, times):
    print(msg * times)

say("Hi")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-17-050c4047a40e> in <module>
#       2     print(msg * times)
#       3
# ----> 4 say("Hi")
#
# TypeError: say() missing 1 required positional argument: 'times'

# %%
def said(a, b=5, c=10):
    print(a)
    print(b)
    print(c)

# %%
said(3,7)
# Out:
# 3
# 7
# 10

# %%
said(25, c = 24)
# Out:
# 25
# 5
# 24

# %%
said(c = 50, a = 100)
# Out:
# 100
# 5
# 50

# %%
i = 0

def change(i):
    i += 1
    return 1

change(1)
print(i)
# Out:
# 0

# %%
print(change(1))
# Out:
# 1

# %%
s = change(1)
print(s)
# Out:
# 1

# %% [markdown]
# # Reference Function

# %%
def multiply(x,y):
    return x * y


operator = multiply       # reference

print(operator(10,20))
#     multiply(10,20)
# Out:
# 200

# %%
def multiply(x,y):
    return x * y


a = multiply       # reference

print(a(10,20))
#     multiply(10,20)
# Out:
# 200

# %%
multiply(5,20)
# Out:
# 100

# %%
a = 10
b = a

print(b)
print(a)
# Out:
# 10
# 10

# %% [markdown]
# # Functions as an Argument

# %%
def sub(x,y):
    return x + y

def add(blue, x, y):     # blue = sub,  x = 5,  y = 10
    return blue(blue(x,y), blue(x,y))
    #       sub(sub(5,10), sub(5,10))
    #       sub(    15   ,    15    )
    #                   30

a = 5
b = 10

print(add(sub, a, b))
# Out:
# 30

# %%
def square(x):
    return x * x

def test(blue, x):
    print(blue(x))
    
test(square, 7)
# Out:
# 49

# %%
def green(red, a):
    print(red(a))
    
green(max,[1,2,3])
green(min,[1,2,3])
# Out:
# 3
# 1

# %%
def printn(x):
    for i in range(x):
        print(i)
        return
    
printn(10)
# Out:
# 0

# %% [markdown]
# # Doc String
#
# Documentation String

# %%
help(max)
# Out:
# Help on built-in function max in module builtins:
#
# max(...)
#     max(iterable, *[, default=obj, key=func]) -> value
#     max(arg1, arg2, *args, *[, key=func]) -> value
#
#     With a single iterable argument, return its biggest item. The
#     default keyword-only argument specifies an object to return if
#     the provided iterable is empty.
#     With two or more arguments, return the largest argument.

# %%
help(print)
# Out:
# Help on built-in function print in module builtins:
#
# print(...)
#     print(value, ..., sep=' ', end='\n', file=sys.stdout, flush=False)
#
#     Prints the values to a stream, or to sys.stdout by default.
#     Optional keyword arguments:
#     file:  a file-like object (stream); defaults to the current sys.stdout.
#     sep:   string inserted between values, default a space.
#     end:   string appended after the last value, default a newline.
#     flush: whether to forcibly flush the stream.

# %%
def indore():
    """
    this function will return hello string
    and also print 5
    """
    print("Hello")
    print(5)

# %%
indore()
# Out:
# Hello
# 5

# %%
help(indore)
# Out:
# Help on function indore in module __main__:
#
# indore()
#     this function will return hello string
#     and also print 5

# %%
print(indore.__doc__)      # dunders /  magic methods
# Out:
#     this function will return hello string
#     and also print 5

# %%
indore()
# Out:
# Hello
# 5

# %% [markdown]
# # Lambda Function
#
# anonymous function

# %%
lambda arguments : expression

# %%
def cube(y):
    return y*y*y

g = lambda x: x*x*x

# %%
print(cube(4))
# Out:
# 64

# %%
print(g(7))
# Out:
# 343

# %% [markdown]
# # Filter Function

# %%
n = [11,22,33,44,55]

r = list(filter(lambda x: x%2 == 0 , n))

print(r)
# Out:
# [22, 44]

# %%
n = ["A","B","C"]

r = list(filter(lambda x: x == "A" or x == "C" , n))

print(r)
# Out:
# ['A', 'C']

# %% [markdown]
# # map function

# %%
n = [1,2,3,4,5]

r = list(map(lambda x: x + 5, n))

print(r)
# Out:
# [6, 7, 8, 9, 10]
